# %%
import pandas as pd

# %%
df = pd.read_csv('covid_data.csv')

# %%
new_df = df.iloc[255:485]

# %%
new_df
# Out:
#                                      # Country,Other TotalCases    NewCases  \
# 1   China          227,426        +154        5,226         NaN     220,971
# 2   USA            91,275,149  +24,757    1,048,843         +21  86,646,220
# 3   India          43,767,534  +16,935      525,760         +51  43,097,510
# 4   Brazil         33,301,118  +10,852     675,408          +55  31,556,393
# 5   France         33,016,578  +73,668      150,576         NaN  30,527,965
# ...                                ...           ...        ...         ...
# 226 Niue           29              NaN                      NaN          23
# 227 Western Sahara 10              NaN            1         NaN           9
# 228 MS Zaandam     9               NaN            2         NaN           7
# 229 Tuvalu         3               NaN                      NaN         NaN
# 230 Saint Helena   2               NaN                      NaN           2
#
# ...

# %%
new_df.iloc[0]
# Out:
# #                                                                 +154
# Country,Other                                                   5,226
# TotalCases                                                         NaN
# NewCases                                                       220,971
# TotalDeaths                                                        +94
# NewDeaths                                                        1,229
# TotalRecovered                                                     NaN
# NewRecovered                                                       158
# ActiveCases                                                          4
# Serious,Critical                                           160,000,000
# Tot Cases/1M pop                                               111,163
# Deaths/1M pop                                           1,439,323,776
# TotalTests                                                        Asia
# ...
