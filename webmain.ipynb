# %%
from bs4 import BeautifulSoup
import requests

# %%
#accessing url and geting data 
html_text  = requests.get("https://www.worldometers.info/coronavirus/").text
code = BeautifulSoup(html_text, 'lxml')

# %%
#finding tables
code.table

# %%
# finding tr tags from html 
tags = code.find_all('tr')
# for tag in tags:
#     x=tag.text
#     print(x)

# %%
data = []
for tag in tags:
    x = tag.text
    data.append(x)

# %%
updated_data = []
for i in data:
    updated_data.append(i.split('\n')[1:-1])

# %%
import csv
try:
    with open('covid.csv','w')as f:
        x = csv.writer(f)
        for i in updated_data:
            x.writerow(i)
except:
    print("file already updated!")

# %%
import pandas as pd

# %%
df =pd.read_csv('covid.csv')

# %%
df.head()
# Out:
#    # Country,Other  TotalCases NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0  1         China     227,426     +154      5,226         NaN        220,971
# 1  2           USA  91,275,149  +24,757  1,048,843        21.0     86,646,220
# 2  3         India  43,767,534  +16,935    525,760        51.0     43,097,510
# 3  4        Brazil  33,301,118  +10,852   675,408         55.0     31,556,393
# 4  5        France  33,016,578  +73,668    150,576         NaN     30,527,965
#
#   NewRecovered ActiveCases Serious,Critical  ...     TotalTests     Tests/  \
# 0          +94       1,229              NaN  ...    160,000,000    111,163
# 1      +84,446   3,580,086            4,183  ...  1,060,390,040        NaN
# 2      +16,069     144,264              698  ...    869,425,632    617,646
# 3      +25,841   1,069,317            8,318  ...     63,776,166    295,757
# 4      +17,601   2,338,037              869  ...    271,490,188  4,140,610
#
# ...

# %%
new_df = df[df.axes[1][:17]]
new_df
# Out:
#        #   Country,Other  TotalCases NewCases TotalDeaths  NewDeaths  \
# 0      1           China     227,426     +154      5,226         NaN
# 1      2             USA  91,275,149  +24,757  1,048,843        21.0
# 2      3           India  43,767,534  +16,935    525,760        51.0
# 3      4          Brazil  33,301,118  +10,852   675,408         55.0
# 4      5          France  33,016,578  +73,668    150,576         NaN
# ..   ...             ...         ...      ...         ...        ...
# 225  226            Niue          29      NaN                    NaN
# 226  227  Western Sahara          10      NaN          1         NaN
# 227  228      MS Zaandam           9      NaN          2         NaN
# 228  229          Tuvalu           3      NaN                    NaN
# 229  230    Saint Helena           2      NaN                    NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# ...

# %%
new_df=new_df.rename(columns={'#':"SN", 'Country,Other':'Country','Unnamed: 15':'Continent'})

# %%
new_df.sample(15)
# Out:
#       SN       Country TotalCases NewCases TotalDeaths  NewDeaths  \
# 112  113    Kyrgyzstan    201,329      NaN      2,991         NaN
# 160  161        Guinea     37,358      NaN        443         NaN
# 126  127      Cameroon    120,068      NaN      1,931         NaN
# 207  208         Nauru      6,960      NaN          1         NaN
# 149  150         Gabon     48,289      NaN        306         NaN
# 201  202       Comoros      8,209      NaN        160         NaN
# 14    15     Argentina  9,465,827   +5,666    129,202         8.0
# 22    23      Portugal  5,273,845      NaN     24,369         NaN
# 182  183       Bermuda     16,722      NaN        141         NaN
# 166  167          Mali     31,200       +2        737         NaN
# 105  106       Nigeria    259,007      NaN      3,144         NaN
# 79    80     Sri Lanka    664,448      +34     16,528         NaN
# 104  105       Algeria    266,445      +21      6,875         NaN
# ...

# %%
new_df.fillna(0, inplace=True)

# %%
new_df.isnull().sum()
# Out:
# SN                  0
# Country             0
# TotalCases          0
# NewCases            0
# TotalDeaths         0
# NewDeaths           0
# TotalRecovered      0
# NewRecovered        0
# ActiveCases         0
# Serious,Critical    0
# Tot Cases/1M pop    0
# Deaths/1M pop       0
# TotalTests          0
# Tests/              0
# 1M pop              0
# Continent           0
# Population          0
# dtype: int64

# %%
new_df.shape
# Out:
# (230, 17)

# %%
new_df[new_df['Country']=='China']
# Out:
#    SN Country TotalCases NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0   1   China    227,426     +154      5,226         0.0        220,971
#
#   NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop Deaths/1M pop  \
# 0          +94       1,229                0              158             4
#
#     TotalTests   Tests/          1M pop Continent     Population
# 0  160,000,000  111,163  1,439,323,776       Asia  6,329275,4169
